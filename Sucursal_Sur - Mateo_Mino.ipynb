# %%
# Librerias
#Importar Couchdb
import couchdb

# %%
# Configuración de la conexión a CouchDB
couch = couchdb.Server('http://admin:admin@localhost:5984/')

# %%
# Crear Base de Datos y acceder a ella
db = couch.create("sucursal_sur")
db = couch['sucursal_sur']

# %%
# Bucle for que se repita n veces
for i in range(250):
    documento = {
        "Nombre": "Mateo",
        "Apellido": "Mino",
        "Modelo": "Intel Core i3-4170",
        "Year": "2014",
        "Nucleos": "2",
        "Subprocesos": "4",
        "Graficos": "Gráficos HD Intel 4400",
        "Generacion": "4",
    }
    db.save(documento)

for i in range(250):
    documento = {
        "Nombre": "Mateo",
        "Apellido": "Mino",
        "Modelo": "Intel Core i9-10885H",
        "Year": "2020",
        "Nucleos": "8",
        "Subprocesos": "16",
        "Graficos": "Gráficos UHD Intel Core™",
        "Generacion": "10",
    }
    db.save(documento)

for i in range(250):
    documento = {
        "Nombre": "Mateo",
        "Apellido": "Mino",
        "Modelo": "Intel Core i9-10900K",
        "Year": "2020",
        "Nucleos": "10",
        "Subprocesos": "20",
        "Graficos": "Gráficos UHD Intel 630",
        "Generacion": "10",
    }
    db.save(documento)

for i in range(250):
    documento = {
        "Nombre": "Mateo",
        "Apellido": "Mino",
        "Modelo": "Intel Core i3-8100T",
        "Year": "2018",
        "Nucleos": "4",
        "Subprocesos": "4",
        "Graficos": "Gráficos UHD Intel 630",
        "Generacion": "8",
    }
    db.save(documento)

for i in range(250):
    documento = {
        "Nombre": "Mateo",
        "Apellido": "Mino",
        "Modelo": "Intel Core i3-6100U",
        "Year": "2015",
        "Nucleos": "2",
        "Subprocesos": "4",
        "Graficos": "Intel® HD Graphics 520",
        "Generacion": "6",
    }
    db.save(documento)

for i in range(250):
    documento = {
        "Nombre": "Mateo",
        "Apellido": "Mino",
        "Modelo": "Intel Core i9-10850K",
        "Year": "2020",
        "Nucleos": "10",
        "Subprocesos": "20",
        "Graficos": "Gráficos HD Intel 4400",
        "Generacion": "10",
    }
    db.save(documento)

for i in range(250):
    documento = {
        "Nombre": "Mateo",
        "Apellido": "Mino",
        "Modelo": "Intel Core i9-11900H",
        "Year": "2021",
        "Nucleos": "8",
        "Subprocesos": "16",
        "Graficos": "Intel® UHD Graphics for 11th Gen Intel Processors",
        "Generacion": "11",
    }
    db.save(documento)

for i in range(250):
    documento = {
        "Nombre": "Mateo",
        "Apellido": "Mino",
        "Modelo": "Intel Core i9-12900HX",
        "Year": "2021",
        "Nucleos": "16",
        "Subprocesos": "24",
        "Graficos": "Intel UHD Graphics for 12th Gen Intel Processors",
        "Generacion": "12",
    }
    db.save(documento)

for i in range(250):
    documento = {
        "Nombre": "Mateo",
        "Apellido": "Mino",
        "Modelo": "Intel Core i3-1220PE",
        "Year": "2021",
        "Nucleos": "8",
        "Subprocesos": "12",
        "Graficos": "Intel UHD Graphics for 12th Gen Intel Processors",
        "Generacion": "12",
    }
    db.save(documento)

for i in range(250):
    documento = {
        "Nombre": "Mateo",
        "Apellido": "Mino",
        "Modelo": "Intel Core i5-1135G7",
        "Year": "2020",
        "Nucleos": "4",
        "Subprocesos": "8",
        "Graficos": "Intel Iris Xe Graphics",
        "Generacion": "11",
    }
    db.save(documento)
