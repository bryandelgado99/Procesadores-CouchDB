# %% [markdown]
# ## Base de datos sucursal centro - Procesadores INC.
# ## Realizado por: Bryan Delgado
# ### Fecha: 26-06-2023

# %%
#1. Instalamos e importamos las librerias necesarias
import couchdb

# %%
#2. Enlazamos la dirección local del servidor
couch = couchdb.Server('http://admin:admin@localhost:5984/')

# %%
#3. Creamos la nueva base de datos llamada sucursal_centro
db = couch['sucursal_centro']

# %%
#4. Insertamos datos en la base, un total de 2500 veces
'''Para este caso, vamos a crear 10 registros de información, los mismos que serán ingresados 250 veces en la base'''
for i in range(250):
    documento = {
        "Nombre": "Bryan",
        "Apellido": "Delgado",
        "Modelo": "AMD Ryzen 5 3450u",
        "Year": "2018",
        "Nucleos": "4",
        "Subprocesos": "8",
        "Graficos": "Radeon Vega 8",
        "Generacion": "2da",
    }
    db.save(documento)

for i in range(250):
    documento = {
        "Nombre": "Bryan",
        "Apellido": "Delgado",
        "Modelo": "AMD Ryzen 5 5600G",
        "Year": "2020",
        "Nucleos": "6",
        "Subprocesos": "12",
        "Graficos": "Radeon Vega X",
        "Generacion": "4ta",
    }
    db.save(documento)

for i in range(250):
    documento = {
        "Nombre": "Bryan",
        "Apellido": "Delgado",
        "Modelo": "AMD Ryzen 3 1200",
        "Year": "2017",
        "Nucleos": "4",
        "Subprocesos": "4",
        "Graficos": "No GPU",
        "Generacion": "1ra",
    }
    db.save(documento)

for i in range(250):
    documento = {
        "Nombre": "Bryan",
        "Apellido": "Delgado",
        "Modelo": "AMD Ryzen Embendded V3C14",
        "Year": "2022",
        "Nucleos": "4",
        "Subprocesos": "8",
        "Graficos": "No GPU",
        "Generacion": "2da",
    }
    db.save(documento)

for i in range(250):
    documento = {
        "Nombre": "Bryan",
        "Apellido": "Delgado",
        "Modelo": "Unisoc SC9853I",
        "Year": "2017",
        "Nucleos": "8",
        "Subprocesos": "12",
        "Graficos": "Mali T820",
        "Generacion": "4ta",
    }
    db.save(documento)

for i in range(250):
    documento = {
        "Nombre": "Bryan",
        "Apellido": "Delgado",
        "Modelo": "Unisoc Tiger T710",
        "Year": "2019",
        "Nucleos": "4",
        "Subprocesos": "8",
        "Graficos": "PowerVM GR 9446",
        "Generacion": "1ra",
    }
    db.save(documento)

for i in range(250):
    documento = {
        "Nombre": "Bryan",
        "Apellido": "Delgado",
        "Modelo": "AMD Ryzen 9 5900HS Creator Edition",
        "Year": "2020",
        "Nucleos": "8",
        "Subprocesos": "16",
        "Graficos": "Radeon Vega 8",
        "Generacion": "4ta",
    }
    db.save(documento)

for i in range(250):
    documento = {
        "Nombre": "Bryan",
        "Apellido": "Delgado",
        "Modelo": "AMD Ryzen 3 4200G",
        "Year": "2020",
        "Nucleos": "4",
        "Subprocesos": "8",
        "Graficos": "Radeon Vega 6",
        "Generacion": "3ra",
    }
    db.save(documento)

for i in range(250):
    documento = {
        "Nombre": "Bryan",
        "Apellido": "Delgado",
        "Modelo": "AMD Ryzen 9 7900",
        "Year": "2022",
        "Nucleos": "12",
        "Subprocesos": "24",
        "Graficos": "Radeon Graphics Raphael",
        "Generacion": "5ta",
    }
    db.save(documento)

for i in range(250):
    documento = {
        "Nombre": "Bryan",
        "Apellido": "Delgado",
        "Modelo": "AMD Ryzen Threadripper Pro 3945WX",
        "Year": "2021",
        "Nucleos": "12",
        "Subprocesos": "24",
        "Graficos": "No GPU",
        "Generacion": "2da",
    }
    db.save(documento)
