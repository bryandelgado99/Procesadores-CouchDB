# %%
#Importar libreria necesaria
import couchdb

# %%
couch = couchdb.Server('http://admin:admin@localhost:5984')

# %%
db = couch['sucursal_valles']

# %%
#Procesadores MediaTek
for i in range(250):
    documento = {
        "Nombre": "Melany",
        "Apellido": "Sangucho",
        "Modelo": "MediaTek MT6739",
        "Year": "2017",
        "Nucleos": "4",
        "Subprocesos": "4",
        "Graficos": "PowerVR GE8100 MP1",
        "Generacion": "1era",
    }
    db.save(documento)

for i in range(250):
    documento = {
        "Nombre": "Melany",
        "Apellido": "Sangucho",
        "Modelo": "MediaTek Helio G88",
        "Year": "2020",
        "Nucleos": "8",
        "Subprocesos": "8",
        "Graficos": "ARM Mali-G52 MC2",
        "Generacion": "1era",
    }
    db.save(documento)
    
for i in range(250):
    documento = {
        "Nombre": "Melany",
        "Apellido": "Sangucho",
        "Modelo": "MediaTek Dimensity 9200",
        "Year": "2022",
        "Nucleos": "8",
        "Subprocesos": "8",
        "Graficos": "ARM Immortalis-G715",
        "Generacion": "1era",
    }
    db.save(documento)
    
for i in range(250):
    documento = {
        "Nombre": "Melany",
        "Apellido": "Sangucho",
        "Modelo": "MediaTek Dimensity 1080",
        "Year": "2022",
        "Nucleos": "8",
        "Subprocesos": "8",
        "Graficos": "ARM Mali-G68 MC4",
        "Generacion": "1era",
    }
    db.save(documento)
    
for i in range(250):
    documento = {
        "Nombre": "Melany",
        "Apellido": "Sangucho",
        "Modelo": "MediaTek Helio P10",
        "Year": "2015",
        "Nucleos": "8",
        "Subprocesos": "8",
        "Graficos": "ARM Mali-T860 MP2",
        "Generacion": "1era",
    }
    db.save(documento)

#Procesadores Snapdragon
for i in range(250):
    documento = {
        "Nombre": "Melany",
        "Apellido": "Sangucho",
        "Modelo": "Snapdragon 8 Gen 2 Mobile Plataform",
        "Year": "2023",
        "Nucleos": "8",
        "Subprocesos": "8",
        "Graficos": "Qualcomm Adreno 740",
        "Generacion": "2da",
    }
    db.save(documento)

for i in range(250):
    documento = {
        "Nombre": "Melany",
        "Apellido": "Sangucho",
        "Modelo": "Snapdragon 8+ Gen 1 Mobile Plataform",
        "Year": "2022",
        "Nucleos": "8",
        "Subprocesos": "8",
        "Graficos": "Qualcomm Adreno 730",
        "Generacion": "1era",
    }
    db.save(documento)
    
for i in range(250):
    documento = {
        "Nombre": "Melany",
        "Apellido": "Sangucho",
        "Modelo": "Snapdragon 870 5G Mobile Plataform",
        "Year": "2021",
        "Nucleos": "8",
        "Subprocesos": "8",
        "Graficos": "Qualcomm Adreno 650",
        "Generacion": "1era",
    }
    db.save(documento)
    
for i in range(250):
    documento = {
        "Nombre": "Melany",
        "Apellido": "Sangucho",
        "Modelo": "Snapdragon 820 Mobile Plataform",
        "Year": "2016",
        "Nucleos": "4",
        "Subprocesos": "4",
        "Graficos": "Qualcomm Adreno 530",
        "Generacion": "1era",
    }
    db.save(documento)
    
for i in range(250):
    documento = {
        "Nombre": "Melany",
        "Apellido": "Sangucho",
        "Modelo": "Snapdragon 888+ 5G Mobile Plataform",
        "Year": "2021",
        "Nucleos": "8",
        "Subprocesos": "8",
        "Graficos": "Qualcomm Adreno 660",
        "Generacion": "1era",
    }
    db.save(documento)
